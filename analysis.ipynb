# %%
import mnist
import main
fetch = mnist.fetch_minist_for_hopfield(size=5, error_rates=[0.1, 0.14, 0.25, 0.3, 0.5])
bias = 60
# Out:
# start to fetch mnist_784 data from openml.org
# finish to fetch mnist_784 data from openml.org

# %% [markdown]
# Error = 0.1

# %%
main.save_mnist_prediction(fetch=fetch[0], bias=bias, sync=False)

# %% [markdown]
# Error = 0.14

# %%
main.save_mnist_prediction(fetch=fetch[1], bias=bias, sync=False)

# %% [markdown]
# Error = 0.25

# %%
main.save_mnist_prediction(fetch=fetch[2], bias=bias, sync=False)

# %% [markdown]
# Error = 0.3

# %%
main.save_mnist_prediction(fetch=fetch[3], bias=bias, sync=False)

# %% [markdown]
# Error = 0.5

# %%
main.save_mnist_prediction(fetch=fetch[4], bias=bias, sync=False)

# %%
main.save_mnist_prediction(fetch=fetch[4], bias=bias, sync=True)

# %% [markdown]
# 7 wzorców

# %%
fetch2 = mnist.fetch_minist_for_hopfield(size=7, error_rates=[0.1, 0.14, 0.25, 0.3, 0.5])
# Out:
# start to fetch mnist_784 data from openml.org
# finish to fetch mnist_784 data from openml.org

# %%
bias = 50

# %% [markdown]
# Error = 0.1

# %%
main.save_mnist_prediction(fetch=fetch2[0], bias=bias, sync=False)

# %% [markdown]
# Error = 0.14

# %%
main.save_mnist_prediction(fetch=fetch2[1], bias=bias, sync=False)

# %%
main.save_mnist_prediction(fetch=fetch2[1], bias=bias, sync=True)
